# %%
# import requests
# from bs4 import BeautifulSoup
# feed = "https://www.theguardian.com/us-news/donaldtrump/rss"
# response=requests.get(feed)
# webpage=response.content
# soup=BeautifulSoup(webpage,features="xml")
# items=soup.find_all("item")
# articles=[]
# for item in items:
#     link=item.find("link").text
#     articles.append(link)
# print(articles)

# %%
import pandas as pd
df=pd.read_csv("/Users/athulkrishnavv/Desktop/ElectoAI/DataFrame.csv")

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df['Sentiment'] = df['Polarity'].apply(lambda x: "Positive" if x > 0.05 else "Negative" if x < -0.05 else "Neutral")
df.to_csv("DataFrame.csv")

# %%
df
# Out:
#                                                 Title  \
# 0   100 Days Into Trump's Second Term: What's Chan...
# 1   After the Arrests and Bullets, Trump Takes on ...
# 2   In Alabama Commencement Speech, Trump Mixes In...
# 3             Trump Posts an Image of Himself as Pope
# 4   Trump Says He Wants Alcatraz Restored as a Prison
# 5   Carney Tells Trump Canada ‘Is Not for Sale’ Du...
# 6   Trump Administration to Announce Trade Deal Wi...
# 7   A Leaked Memo Reveals Details About Trump’s Wa...
# 8   DOGE Killed Dozens of Grants That Supported Wo...
# 9   North Carolina GOP Judge Finally Concedes Afte...
# 10  Trump Is Eager to Defund Harvard, Yet Publicly...
# 11  Nikole Hannah-Jones: Trump Is Erasing Black Hi...
# 12  Is the New Pope MAGA or Woke? Depends Whom You...
# 13   Trump Administration Fires Librarian of Congress
# 14               The Brain Rot Cabinet – Mother Jones
# 15  Trump’s New Surgeon General Pick Wants to “Rai...
# ...

# %%
df['id'] = range(1, 50)

# %%
from textblob import TextBlob

# %%
# from newspaper import Article
# import nltk
# import pandas as pd
# from textblob import TextBlob

# # Download required NLTK data
# nltk.download('punkt')
# nltk.download('punkt_tab')

# # Initialize an empty list to store article data
# data_list = []

# # Iterate over the list of article URLs
# for url in articles:
#     try:
#         # Initialize and process the article
#         article = Article(url)
#         article.download()
#         article.parse()
#         article.nlp()

#         # Extract relevant information
#         title = article.title
#         summary = article.summary
#         keywords = article.keywords
#         text = article.text
#         date = article.publish_date

#         # Perform sentiment analysis
#         text_blob = TextBlob(text)
#         polarity = text_blob.polarity
#         subjectivity = text_blob.subjectivity

#         # Store the data as a dictionary
#         data = {
#             'Title': title,
#             'Summary': summary,
#             'Keywords': keywords,
#             'Text': text,
#             'Publish_Date': date,
#             'Polarity': polarity,
#             'Subjectivity': subjectivity
#         }

#         # Append the dictionary to the list
#         data_list.append(data)

#         # Print article details (optional, for debugging)
#         print("***************************************")
#         print(f"Title: {title}")
#         print(f"Summary: {summary}")
#         print(f"Keywords: {keywords}")
#         print(f"Polarity: {polarity}")
#         print(f"Subjectivity: {subjectivity}")
#         print(f"Text: {text}")
#         print(f"Date: {date}")
#         print("***************************************")

#     except Exception as e:
#         print(f"Error processing {url}: {e}")

# # Create a pandas DataFrame from the list of dictionaries
# df = pd.DataFrame(data_list)

# # Display the DataFrame
# print(df)

# # Optionally, save the DataFrame to a CSV file
# df.to_csv('articles_data.csv', index=False)

# %%
# df2=pd.read_csv("/Users/athulkrishnavv/Desktop/ElectoAI/Dataframe2.csv")

# %%
# df3=pd.read_csv("/Users/athulkrishnavv/Desktop/ElectoAI/Dataframe3.csv")

# %%
# result = pd.concat([df, df2, df3], axis=0)
# print(result)

# %%
# df=result

# %%
# df.reset_index(drop=True,inplace=True)

# %%
# df.dtypes

# %%
df.isna().sum()
# Out:
# Title           0
# Summary         0
# Keywords        0
# Publish_Date    0
# Polarity        0
# Subjectivity    0
# id              0
# Sentiment       0
# dtype: int64

# %%
df.Keywords[0]
# Out:
# 'changed, days, american, china, second, musk, federal, trumps, united, whats, trump, 100, tariffs, states, mr, immigration, president, term'

# %%
df['Keywords'] = df['Keywords'].apply(lambda x: ', '.join(x) if isinstance(x, list) else str(x))

# %%
df['Keywords']=df['Keywords'].apply(lambda x: x.strip('"[]"'))

# %%
df['Keywords']=df['Keywords'].apply(lambda x: x.strip('"'))

# %%
df['Keywords'] = df['Keywords'].apply(lambda x: ", ".join([word.strip(" '\"") for word in str(x).split(',')]))

# %%
df.Keywords[21]
# Out:
# 'longer, victims, going, assist, disaster, fema, canvassing, survivors, states, agency, doortodoor, memo, federal'

# %%
df.duplicated().sum()
# Out:
# 0

# %%
def format_publish_date(date):
    return pd.to_datetime(date).date().strftime('%Y-%m-%d')

# Apply it to the column
df["Publish_Date"] = df["Publish_Date"].apply(format_publish_date)

# %%
df
# Out:
#                                                 Title  \
# 0   100 Days Into Trump's Second Term: What's Chan...
# 1   After the Arrests and Bullets, Trump Takes on ...
# 2   In Alabama Commencement Speech, Trump Mixes In...
# 3             Trump Posts an Image of Himself as Pope
# 4   Trump Says He Wants Alcatraz Restored as a Prison
# 5   Carney Tells Trump Canada ‘Is Not for Sale’ Du...
# 6   Trump Administration to Announce Trade Deal Wi...
# 7   A Leaked Memo Reveals Details About Trump’s Wa...
# 8   DOGE Killed Dozens of Grants That Supported Wo...
# 9   North Carolina GOP Judge Finally Concedes Afte...
# 10  Trump Is Eager to Defund Harvard, Yet Publicly...
# 11  Nikole Hannah-Jones: Trump Is Erasing Black Hi...
# 12  Is the New Pope MAGA or Woke? Depends Whom You...
# 13   Trump Administration Fires Librarian of Congress
# 14               The Brain Rot Cabinet – Mother Jones
# 15  Trump’s New Surgeon General Pick Wants to “Rai...
# ...

# %%
df["Publish_Date"] = df["Publish_Date"].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d'))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure Date column is in datetime format
df['Publish_Date'] = pd.to_datetime(df['Publish_Date'], format='%Y-%m-%d')

# Sort by Date (optional but useful for trends)
df = df.sort_values('Publish_Date')

# Plot
plt.figure(figsize=(12, 6))
plt.plot(df['Publish_Date'], df['Polarity'], marker='o', linestyle='-', color='blue')
plt.title('Sentiment Polarity Trend Over Time')
plt.xlabel('Publish_Date')
plt.ylabel('Polarity')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# df['Sentiment']=df['Polarity'].apply(lambda x:"Positive" if x>0.01 else "Negative" if x<0 else "Nuetral")

# %%
df
# Out:
#                                                 Title  \
# 0   100 Days Into Trump's Second Term: What's Chan...
# 1   After the Arrests and Bullets, Trump Takes on ...
# 2   In Alabama Commencement Speech, Trump Mixes In...
# 3             Trump Posts an Image of Himself as Pope
# 4   Trump Says He Wants Alcatraz Restored as a Prison
# 5   Carney Tells Trump Canada ‘Is Not for Sale’ Du...
# 11  Nikole Hannah-Jones: Trump Is Erasing Black Hi...
# 10  Trump Is Eager to Defund Harvard, Yet Publicly...
# 9   North Carolina GOP Judge Finally Concedes Afte...
# 8   DOGE Killed Dozens of Grants That Supported Wo...
# 7   A Leaked Memo Reveals Details About Trump’s Wa...
# 6   Trump Administration to Announce Trade Deal Wi...
# 22  ‘JD Vance se equivoca’: el nuevo papa parecía ...
# 21  FEMA Will No Longer Go Door-to-Door to Assist ...
# 20  Ed Martin’s Derailed Nomination Shows Donald T...
# 19  Trump Administration Updates: U.S. and Britain...
# ...

# %%
df['Keywords'][21]
# Out:
# 'longer, victims, going, assist, disaster, fema, canvassing, survivors, states, agency, doortodoor, memo, federal'

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    34
# Neutral     13
# Negative     2
# Name: count, dtype: int64

# %%
df.to_csv("DataFrame.csv")

# %%
df
# Out:
#                                                 Title  \
# 0   100 Days Into Trump's Second Term: What's Chan...
# 1   After the Arrests and Bullets, Trump Takes on ...
# 2   In Alabama Commencement Speech, Trump Mixes In...
# 3             Trump Posts an Image of Himself as Pope
# 4   Trump Says He Wants Alcatraz Restored as a Prison
# 5   Carney Tells Trump Canada ‘Is Not for Sale’ Du...
# 11  Nikole Hannah-Jones: Trump Is Erasing Black Hi...
# 10  Trump Is Eager to Defund Harvard, Yet Publicly...
# 9   North Carolina GOP Judge Finally Concedes Afte...
# 8   DOGE Killed Dozens of Grants That Supported Wo...
# 7   A Leaked Memo Reveals Details About Trump’s Wa...
# 6   Trump Administration to Announce Trade Deal Wi...
# 22  ‘JD Vance se equivoca’: el nuevo papa parecía ...
# 21  FEMA Will No Longer Go Door-to-Door to Assist ...
# 20  Ed Martin’s Derailed Nomination Shows Donald T...
# 19  Trump Administration Updates: U.S. and Britain...
# ...

# %%
from collections import Counter

# Ensure Keywords are cleaned and split properly
all_keywords = []

for row in df['Keywords'].dropna():
    # Remove unwanted characters and split into words
    words = row.replace("[", "").replace("]", "").replace("'", "").split(",")
    cleaned_words = [word.strip() for word in words if word.strip()]
    all_keywords.extend(cleaned_words)

# Count and extract top 10
keyword_counts = Counter(all_keywords)
top_3_keywords = keyword_counts.most_common(10)

print("Top 10 keywords:")
for word, freq in top_3_keywords:
    print(f"{word} (Frequency: {freq})")
# Out:
# Top 10 keywords:
# trump (Frequency: 33)
# trumps (Frequency: 10)
# president (Frequency: 10)
# white (Frequency: 10)
# mr (Frequency: 7)
# trade (Frequency: 7)
# administration (Frequency: 7)
# house (Frequency: 6)
# federal (Frequency: 5)
# states (Frequency: 5)

# %%
df.dtypes
# Out:
# Title                   object
# Summary                 object
# Keywords                object
# Publish_Date    datetime64[ns]
# Polarity               float64
# Subjectivity           float64
# id                       int64
# Sentiment               object
# dtype: object

# %%
ax = df['Sentiment'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Sentiment',
          figsize=(10, 5))
ax.set_xlabel('Sentiment Class')
plt.show()

# %%
example=df['Summary'][10]
print(example)
# Out:
# According to a 2024 report from Media Matters, Martin has called himself a “big admirer” of the nonprofit group.
# Media Matters wrote:Martin also repeatedly hosted VDare leader and white nationalist Peter Brimelow on his now-defunct radio program The Ed Martin Movement.
# In 2018, too, the Trump administration reinstated the tax-exempt status of white nationalist Richard Spencer‘s National Policy Institute, which had its status revoked automatically for failing to file mandatory 990 tax returns for three years running.
# It is telling that a president who never questioned the tax-exempt status of white nationalist groups is now suggesting his IRS might take a hard look at Harvard’s.
# He’s Black.”Taylor’s New Century Foundation also appears to be inactive these days, and an entirely unrelated nonprofit exists under the same name.

# %% [markdown]
# Roberta pretrained model

# %%
df.reset_index(drop=True,inplace=True)

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.36437362, 'roberta_neu': 0.55525225, 'roberta_pos': 0.08037419}

# %%
from tqdm.notebook import tqdm

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
from tqdm import tqdm

res = {}

for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Summary']
        myid = row['id']

        # RoBERTa sentiment analysis only
        roberta_result = polarity_scores_roberta(text)
        res[myid] = roberta_result

    except RuntimeError:
        print(f"Broke for id {myid}")
# Out:
# 100%|██████████| 49/49 [00:03<00:00, 12.54it/s]

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'id'})
results_df = results_df.merge(df, how='left')

# %%
results_df
# Out:
#     id  roberta_neg  roberta_neu  roberta_pos  \
# 0    1     0.059635     0.452331     0.488034
# 1    2     0.246490     0.641492     0.112017
# 2    3     0.244836     0.568160     0.187004
# 3    4     0.424448     0.524016     0.051536
# 4    5     0.629294     0.330709     0.039998
# 5    6     0.079256     0.665524     0.255220
# 6   12     0.179996     0.510326     0.309678
# 7   11     0.364374     0.555252     0.080374
# 8   10     0.326505     0.603988     0.069507
# 9    9     0.339373     0.587615     0.073012
# 10   8     0.764262     0.222348     0.013390
# 11   7     0.010713     0.359636     0.629651
# 12  23     0.167021     0.785815     0.047164
# 13  22     0.485464     0.459494     0.055042
# 14  21     0.779957     0.209089     0.010953
# 15  20     0.545983     0.410091     0.043926
# 16  19     0.564229     0.402158     0.033614
# 17  15     0.627623     0.338053     0.034324
# 18  17     0.521285     0.444659     0.034056
# ...

# %%
import seaborn as sns

# %%
results_df.query("Sentiment == 'positive'").shape
# Out:
# (0, 11)

# %%
results_df
# Out:
#     id  roberta_neg  roberta_neu  roberta_pos  \
# 0    1     0.059635     0.452331     0.488034
# 1    2     0.246490     0.641492     0.112017
# 2    3     0.244836     0.568160     0.187004
# 3    4     0.424448     0.524016     0.051536
# 4    5     0.629294     0.330709     0.039998
# 5    6     0.079256     0.665524     0.255220
# 6   12     0.179996     0.510326     0.309678
# 7   11     0.364374     0.555252     0.080374
# 8   10     0.326505     0.603988     0.069507
# 9    9     0.339373     0.587615     0.073012
# 10   8     0.764262     0.222348     0.013390
# 11   7     0.010713     0.359636     0.629651
# 12  23     0.167021     0.785815     0.047164
# 13  22     0.485464     0.459494     0.055042
# 14  21     0.779957     0.209089     0.010953
# 15  20     0.545983     0.410091     0.043926
# 16  19     0.564229     0.402158     0.033614
# 17  15     0.627623     0.338053     0.034324
# 18  17     0.521285     0.444659     0.034056
# ...

# %%
results_df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    34
# Neutral     13
# Negative     2
# Name: count, dtype: int64

# %%
results_df[results_df['Sentiment'].str.lower() == 'positive'] \
    .sort_values('roberta_pos', ascending=False)['Summary'].values[0]
# Out:
# 'Justice Sotomayor indicated that she had a different conception of what lawyers ought to do.\n“We need trained and passionate and committed lawyers to fight this fight,” she said.\n“For me, being here with you is an act of solidarity.”Justice Sotomayor’s remarks came in a charged setting, at an awards ceremony at the National Museum of African American History and Culture, which is part of the Smithsonian Institution.\nIn her remarks, Justice Sotomayor took a different view.\n“Diversity is important for its own sake,” she said, “because it inspires everyone to believe that it is possible for them to be in a position to help others.”'

# %%
results_df[results_df['Sentiment'].str.lower() == 'negative'] \
    .sort_values('roberta_neg', ascending=False)['Summary'].values[0]
# Out:
# 'President Trump said on Sunday that he wanted federal law enforcement agencies to work on restoring Alcatraz, now a museum, to a functioning maximum-security prison.\nRepeating one of his constant refrains that the United States had become a dangerous, lawless place, Mr. Trump wrote on social media that he wanted Alcatraz, an island in San Francisco Bay, to be enlarged and rebuilt “to house America’s most ruthless and violent offenders.\nWe will no longer be held hostage to criminals, thugs, and judges that are afraid to do their job and allow us to remove criminals, who came into our country illegally.”It was not immediately clear how his musing could be put into action, given that any such project would be extraordinarily expensive and that the administration already planned to cut billions of dollars from the Justice Department budget.\nMr. Trump said he had instructed the Bureau of Prisons, the Justice Department and the Homeland Security Department to work on his idea, along wi
# ...

# %%
results_df[results_df['Sentiment'].str.lower() == 'neutral'] \
    .sort_values('roberta_neu', ascending=False)['Summary'].values[0]
# Out:
# 'La salud de los niñosMuchos de los hijos de padres migrantes que no han ido a sus citas o por sus medicamentos son ciudadanos estadounidenses.\nSin embargo, en las familias de estatus mixto los padres que podrían ser deportados a menudo no están dispuestos a correr el riesgo de ir a la clínica o a la farmacia.\nUn pediatra de un centro de salud que da servicio a poblaciones desatendidas en la costa central de California informó de un aumento del 30 por ciento en las ausencias a las citas pediátricas.\nAlgunos padres de niños en otras situaciones graves —como los que reciben tratamiento contra el cáncer— tienen la esperanza de que el estado de su hijo pueda protegerlos.\nAlgunos han pedido a los pediatras cartas donde expliquen los requisitos médicos de sus hijos, con la esperanza de que los funcionarios de migración que los detengan puedan convencerse de que el niño necesita quedarse en Estados Unidos para sobrevivir.'

# %%
top_pos = results_df.sort_values('roberta_pos', ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(data=top_pos, y='Title', x='roberta_pos', palette='Greens_d')
plt.title('Top 10 Most Positive Articles (Roberta Score)')
plt.xlabel('Roberta Positive Score')
plt.ylabel('Article Title')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/dr/y1cb750j3hg_wgfxyt1z_pym0000gn/T/ipykernel_87650/1390914499.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_pos, y='Title', x='roberta_pos', palette='Greens_d')

# %%
plt.figure(figsize=(8, 5))
sns.histplot(results_df['Polarity'], bins=20, kde=True)
plt.title('Polarity Score Distribution')
plt.xlabel('Polarity')
plt.ylabel('Frequency')
plt.show()

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0

# %%
sent_pipeline('I love sentiment analysis!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997853636741638}]
